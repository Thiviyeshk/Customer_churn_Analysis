# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df.head(10)
# Out:
#                             Customer_ID               Name  \
# 0  a8b2ac22-dd31-483e-8672-592b7089138f       Brenda Grant
# 1  320c00d8-9b88-44f6-ab57-d46976740ca1  Christopher Wells
# 2  0c6e183c-4af4-4062-b0aa-875f47a0e0d1     Robert Raymond
# 3  c4cf3a80-cbbe-47c5-8340-ef8d149607a7       Glenda Irwin
# 4  366001d6-9bec-4667-b80c-18045a682f7f        Alyssa Luna
# 5  d931ad6a-f9fc-487a-bd00-805a82ecc4e4    Melissa Delgado
# 6  e1d91669-02c9-4dd4-8f06-3177c0107217        Krista Lamb
# 7  a9f93d7a-8cc8-4c46-9348-82395506e2ad     David Perry MD
# 8  142feff0-2907-4811-ad26-3fcf32a1bd88           Mark Orr
# 9  a02ede81-ca19-4be9-bd73-77a1ed9e556a    Luke Villarreal
#
#                       Email  Account_Age_Days Login_Frequency  \
# 0       dhanson@example.com               790          Weekly
# 1        awatts@example.net               399           Daily
# 2   medinaerika@example.org               646           Daily
# 3      aramirez@example.org               113          Weekly
# 4  bergeramanda@example.org               322          Weekly
# 5      seanhall@example.org                 8           Daily
# 6        john17@example.net               436          Rarely
# 7    michelle51@example.net               973          Weekly
# 8     boyledean@example.org               305           Daily
# 9         ecarr@example.com                26           Daily
#
#    Daily_Usage_Mins                                Last_Support_Ticket  Churn
# 0                28          Just checking if my payment went through.      0
# 1                28          Just checking if my payment went through.      1
# 2               110        The integration with Slack works perfectly.      0
# 3                21          Just checking if my payment went through.      0
# 4                 7  Your API documentation is outdated and full of...      1
# 5                40          Just checking if my payment went through.      0
# 6                 3  The UI is too confusing. I can't find the expo...      1
# 7                20          Just checking if my payment went through.      0
# 8                25          Just checking if my payment went through.      0
# 9                35              When will the maintenance window end?      0

# %%
df = df.drop(columns=[
    'Customer_ID',
    'Name',
    'Email',
    'Last_Support_Ticket'
])

# %%
df.head()
# Out:
#    Account_Age_Days Login_Frequency  Daily_Usage_Mins  Churn
# 0               790          Weekly                28      0
# 1               399           Daily                28      1
# 2               646           Daily               110      0
# 3               113          Weekly                21      0
# 4               322          Weekly                 7      1

# %%
df.isnull().sum()
# Out:
# Account_Age_Days    0
# Login_Frequency     0
# Daily_Usage_Mins    0
# Churn               0
# dtype: int64

# %%
df=df.dropna()

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Account_Age_Days  2000 non-null   int64
#  1   Login_Frequency   2000 non-null   object
#  2   Daily_Usage_Mins  2000 non-null   int64
#  3   Churn             2000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 62.6+ KB
#        Account_Age_Days  Daily_Usage_Mins        Churn
# count       2000.000000         2000.0000  2000.000000
# mean         560.969500           36.1610     0.368500
# std          317.349495           29.1486     0.482519
# min            1.000000            1.0000     0.000000
# 25%          287.750000           11.0000     0.000000
# 50%          565.000000           30.0000     0.000000
# 75%          840.000000           53.0000     1.000000
# max         1094.000000          119.0000     1.000000

# %%
df.to_csv("cleaned_churn_data.csv", index=False)

# %%
df = pd.read_csv("cleaned_churn_data.csv")

# %%
df.head()
# Out:
#    Account_Age_Days Login_Frequency  Daily_Usage_Mins  Churn
# 0               790          Weekly                28      0
# 1               399           Daily                28      1
# 2               646           Daily               110      0
# 3               113          Weekly                21      0
# 4               322          Weekly                 7      1

# %%
df['Login_Frequency'].unique()
# Out:
# array(['Weekly', 'Daily', 'Rarely'], dtype=object)

# %%
df.head(40)
# Out:
#     Account_Age_Days Login_Frequency  Daily_Usage_Mins  Churn
# 0                790          Weekly                28      0
# 1                399           Daily                28      1
# 2                646           Daily               110      0
# 3                113          Weekly                21      0
# 4                322          Weekly                 7      1
# 5                  8           Daily                40      0
# 6                436          Rarely                 3      1
# 7                973          Weekly                20      0
# 8                305           Daily                25      0
# 9                 26           Daily                35      0
# 10               726          Rarely                 9      1
# 11               911           Daily                18      0
# 12              1017          Rarely                 7      1
# 13               791           Daily                17      0
# 14               599           Daily                46      0
# 15                19          Weekly                26      0
# 16               691          Rarely                 1      1
# 17               496          Rarely                11      1
# 18               691           Daily                32      1
# 19                 8           Daily                57      0
# 20                64          Weekly                57      0
# 21               922          Weekly                27      0
# 22                98          Rarely                 2      1
# 23               710          Weekly                51      0
# 24               152           Daily                38      0
# 25               466          Weekly                41      0
# 26               366          Rarely                 2      1
# 27               747          Weekly                10      1
# 28               892          Weekly                13      1
# 29              1044           Daily                81      0
# 30               112          Weekly                 8      1
# 31               330          Rarely                 8      1
# 32               440          Weekly                 1      1
# 33              1083          Weekly                55      0
# 34               801           Daily                23      0
# 35               139          Rarely                12      0
# 36               968          Weekly                47      0
# 37               570           Daily               105      0
# 38               383          Weekly                39      0
# 39               382           Daily                58      0

# %%
df['Login_Frequency'] = df['Login_Frequency'].map({
    'Daily': 4,
    'Weekly': 3,
    'Monthly': 2,
    'Rarely': 1
})

# %%
df['Login_Frequency'].unique()
# Out:
# array([3, 4, 1])

# %%
df.to_csv("encoded_churn_data.csv", index=False)

# %%
df['Login_Frequency'].value_counts()
# Out:
# Login_Frequency
# 4    868
# 3    795
# 1    337
# Name: count, dtype: int64

# %%
df.to_csv("encoded_churn_data.csv", index=False)

# %%
churn_rate = df['Churn'].mean() * 100
print("Churn Rate:", churn_rate)
# Out:
# Churn Rate: 36.85

# %%
import matplotlib.pyplot as plt

df['Churn'].value_counts().plot(kind='bar')

plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")

plt.show()

# %%
import seaborn as sns
sns.boxplot(x='Churn', y='Daily_Usage_Mins', data=df)
plt.title("Daily Usage vs Churn")
plt.show()

# %%
sns.boxplot(x='Churn', y='Login_Frequency', data=df)
plt.title("Login Frequency vs Churn")
plt.show()

# %%
sns.boxplot(x='Churn', y='Account_Age_Days', data=df)
plt.title("Account Age vs Churn")
plt.show()

# %%
df.columns
# Out:
# Index(['Account_Age_Days', 'Login_Frequency', 'Daily_Usage_Mins', 'Churn'], dtype='object')

# %%
x=df[['Account_Age_Days',
      'Login_Frequency',
      'Daily_Usage_Mins']]

# %%
y=df['Churn']

# %%
x.head()
# Out:
#    Account_Age_Days  Login_Frequency  Daily_Usage_Mins
# 0               790                3                28
# 1               399                4                28
# 2               646                4               110
# 3               113                3                21
# 4               322                3                 7

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("encoded_churn_data.csv")

# %%
x=df[['Account_Age_Days','Login_Frequency','Daily_Usage_Mins']]
y=df['Churn']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,y, test_size=0.2, random_state=42
)

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7975

# %%
precision = precision_score(y_test,y_pred)
print('Precision:', precision)
# Out:
# Precision: 0.7479674796747967

# %%
recall = recall_score(y_test,y_pred)
print("Recall:",recall)
# Out:
# Recall: 0.647887323943662

# %%
df['Churn_Prediction'] = model.predict(x)

# %%
df.head()
# Out:
#    Account_Age_Days  Login_Frequency  Daily_Usage_Mins  Churn  \
# 0               790                3                28      0
# 1               399                4                28      1
# 2               646                4               110      0
# 3               113                3                21      0
# 4               322                3                 7      1
#
#    Churn_Prediction
# 0                 0
# 1                 1
# 2                 0
# 3                 0
# 4                 1

# %%
df['Rish_Level'] = df['Churn_Prediction'].map({
    1:'High Risk',
    0:'Safe'
})

# %%
df.head()
# Out:
#    Account_Age_Days  Login_Frequency  Daily_Usage_Mins  Churn  \
# 0               790                3                28      0
# 1               399                4                28      1
# 2               646                4               110      0
# 3               113                3                21      0
# 4               322                3                 7      1
#
#    Churn_Prediction Rish_Level
# 0                 0       Safe
# 1                 1  High Risk
# 2                 0       Safe
# 3                 0       Safe
# 4                 1  High Risk

# %%
df.to_csv("churn_dashboard_data.csv", index=False)

# %%
df = pd.read_csv("churn_dashboard_data.csv")

# %%
df.head()
# Out:
#    Account_Age_Days  Login_Frequency  Daily_Usage_Mins  Churn  \
# 0               790                3                28      0
# 1               399                4                28      1
# 2               646                4               110      0
# 3               113                3                21      0
# 4               322                3                 7      1
#
#    Churn_Prediction Rish_Level
# 0                 0       Safe
# 1                 1  High Risk
# 2                 0       Safe
# 3                 0       Safe
# 4                 1  High Risk

# %%
df.insert(0, "Customer_ID", ["CUST" + str(i).zfill(3) for i in range(1, len(df)+1)])

# %%
df.head()
# Out:
#   Customer_ID  Account_Age_Days  Login_Frequency  Daily_Usage_Mins  Churn  \
# 0     CUST001               790                3                28      0
# 1     CUST002               399                4                28      1
# 2     CUST003               646                4               110      0
# 3     CUST004               113                3                21      0
# 4     CUST005               322                3                 7      1
#
#    Churn_Prediction Rish_Level
# 0                 0       Safe
# 1                 1  High Risk
# 2                 0       Safe
# 3                 0       Safe
# 4                 1  High Risk

# %%
df.to_csv("churn_dashboard_data_updated.csv", index=False)

# %%
df.head()
# Out:
#   Customer_ID  Account_Age_Days  Login_Frequency  Daily_Usage_Mins  Churn  \
# 0     CUST001               790                3                28      0
# 1     CUST002               399                4                28      1
# 2     CUST003               646                4               110      0
# 3     CUST004               113                3                21      0
# 4     CUST005               322                3                 7      1
#
#    Churn_Prediction Rish_Level
# 0                 0       Safe
# 1                 1  High Risk
# 2                 0       Safe
# 3                 0       Safe
# 4                 1  High Risk
